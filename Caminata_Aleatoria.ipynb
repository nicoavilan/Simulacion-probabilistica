# %% [markdown]
# <a href="https://colab.research.google.com/github/nicoavilan/Simulacion-probabilistica/blob/main/Caminata_Aleatoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.animation as animation
from IPython.display import HTML

# %%
N = 10**4
x = np.random.rand(N).round(2)
#print(x)
moneda = []
for n in range(N):
  if x[n] > 1/2:
    moneda.append("Sello")
  else:
    moneda.append("Cara")
print("sellos: ",moneda.count("Sello"))
print("caras: ",moneda.count("Cara"))

p = [0]
for n in range(N):
  if moneda[n] == "Cara":
    p.append(p[n]+1)
  else:
    p.append(p[n]-1)
plt.figure(figsize= (10,4))
plt.subplot(1,2,1)
sns.countplot(x = moneda)
plt.subplot(1,2,2)
m = np.arange(N+1)
z = np.zeros(N+1)
plt.plot(p, m)
plt.show()
print("Posición final: ",p[-1])
# Out:
# sellos:  4878
# caras:  5122
# Posición final:  244

# %%
fig=plt.figure()
ax=fig.gca()

def actualizar(i):
  ax.clear()

  ax.plot(p[:i], m[:i],'-')
  ax.plot(p[:i], z[:i],'-')
  ax.set_xlabel("Posición", fontweight="bold", size = 15)
  ax.set_ylabel("Tiempo", fontweight="bold", size = 15)
  ax.plot(p[i],  m[i],'o',markersize=10,color='r', label = "Evolución en\nel tiempo")
  ax.plot(p[i],  0,'o',markersize=10,color='g', label = "Posición")
  ax.legend()

# %%
ani=animation.FuncAnimation(fig, actualizar, range(0,N,20), interval=200)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# La animación se observa al ejecutar el código, GitHub no la genera automáticamente.
